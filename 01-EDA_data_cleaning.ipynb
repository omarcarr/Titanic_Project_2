# %% [markdown]
# # EDA and Data Cleaning
# - This notebook might be where we would perform data cleaning if we were starting this out from scratch

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/omarcarr/Desktop/Notebooks/DSI-US-5/Projects/project-2/train.csv')
kaggle = pd.read_csv('/Users/omarcarr/Desktop/Notebooks/DSI-US-5/Projects/project-2/test.csv')

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour    ...     Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl    ...                0         0     NaN   NaN
# 1       IR1          Lvl    ...                0         0     NaN   NaN
# 2       Reg          Lvl    ...                0         0     NaN   NaN
# 3       Reg          Lvl    ...                0         0     NaN   NaN
# 4       IR1          Lvl    ...                0         0     NaN   NaN
#
# ...

# %% [markdown]
# - The amount of null valuse per column isn't particularly constant, with some exceptions.  The `Garage` null valuse probably come from the same rows:

# %%
df.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# Pool QC           2042
# Misc Feature      1986
# Alley             1911
# Fence             1651
# Fireplace Qu      1000
# Lot Frontage       330
# Garage Finish      114
# Garage Cond        114
# Garage Qual        114
# Garage Yr Blt      114
# Garage Type        113
# Bsmt Exposure       58
# BsmtFin Type 2      56
# BsmtFin Type 1      55
# Bsmt Cond           55
# dtype: int64

# %%
df._get_numeric_data()
# Out:
#         Id        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      109  533352170           60           NaN     13517             6
# 1      544  531379050           60          43.0     11492             7
# 2      153  535304180           20          68.0      7922             5
# 3      318  916386060           60          73.0      9802             5
# 4      255  906425045           50          82.0     14235             6
# 5      138  535126040           20         137.0     16492             6
# 6     2827  908186070          180          35.0      3675             6
# 7      145  535154050           20           NaN     12160             5
# 8     1942  535353130           20           NaN     15783             5
# 9     1956  535426130           60          70.0     11606             5
# 10    1044  527451290          160          21.0      1680             6
# 11    2752  906380150           20          64.0      7488             7
# ...

# %%
df.select_dtypes(include='number')
# Out:
#         Id        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      109  533352170           60           NaN     13517             6
# 1      544  531379050           60          43.0     11492             7
# 2      153  535304180           20          68.0      7922             5
# 3      318  916386060           60          73.0      9802             5
# 4      255  906425045           50          82.0     14235             6
# 5      138  535126040           20         137.0     16492             6
# 6     2827  908186070          180          35.0      3675             6
# 7      145  535154050           20           NaN     12160             5
# 8     1942  535353130           20           NaN     15783             5
# 9     1956  535426130           60          70.0     11606             5
# 10    1044  527451290          160          21.0      1680             6
# 11    2752  906380150           20          64.0      7488             7
# ...

# %%
df_numbers = df.select_dtypes(include='number')

# %%
df_objects = df.select_dtypes(exclude='number')

# %%
df_numbers.shape
# Out:
# (2051, 39)

# %%
df_objects.shape
# Out:
# (2051, 42)

# %%
df_numbers.fillna(0.0)
# Out:
#         Id        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0      109  533352170           60           0.0     13517             6
# 1      544  531379050           60          43.0     11492             7
# 2      153  535304180           20          68.0      7922             5
# 3      318  916386060           60          73.0      9802             5
# 4      255  906425045           50          82.0     14235             6
# 5      138  535126040           20         137.0     16492             6
# 6     2827  908186070          180          35.0      3675             6
# 7      145  535154050           20           0.0     12160             5
# 8     1942  535353130           20           0.0     15783             5
# 9     1956  535426130           60          70.0     11606             5
# 10    1044  527451290          160          21.0      1680             6
# 11    2752  906380150           20          64.0      7488             7
# ...

# %% [markdown]
# -For now, we are using a very simple method of imputation.  This is a first pass at cleaning the data, and later we can come back to do something a little more sophisticated.
#
# -Choosing to impute with `0` rather than the mean, median, or mode because we assume the null values in the dataset have meaning and indicate the absence of a feature.

# %%
df_numbers.fillna(0.0).to_csv('/Users/omarcarr/Desktop/Notebooks/DSI-US-5/Projects/project-2/train_numbers_clean.csv', index=False)

# %%
kaggle.select_dtypes(
    include='number').fillna(
    0.0).to_csv(
    '/Users/omarcarr/Desktop/Notebooks/DSI-US-5/Projects/project-2/kaggle_numbers_clean.csv', index=False)

# %% [markdown]
# -The cleaned numeric datasets are being exported to the folder I have my datasets in
